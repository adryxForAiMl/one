# %% [markdown]
# #fixed point iteration method

# %%
import numpy as np
import matpotlib.pyplot as plt
def fixed_point_iteration(g,x0,tol=1e-6,max_iter=100):
    """
    parametersa:
    g(function): Function representing the iteration g(x).
    x0 (flot): Tolerance for stoping criterion.
    max_iter (list):Error and root approximations at each iteration.

    return:
    root(float): Approximated root.
    errr_table (list): Error and root approximations at each iteration.
    """
    x=x0
    error_table=[]
    for i in range(max_iter):
        x_next=g(x)
        error=abs(x_next-x)
        error_table
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import matpotlib.pyplot as plt
#       3 def fixed_point_iteration(g,x0,tol=1e-6,max_iter=100):
#       4     """
#       5     parametersa:
#
# ModuleNotFoundError: No module named 'matpotlib'

# %%
import numpy as np
import
