# %% [markdown]
# how to define a function
# python functions: it can be define with the def

# %%
def my_function():
    print("hello from inside the function")

# %%
my_function()
# Out:
# hello from inside the function

# %%
def my_function(fname):
    print(fname+ " kumar")

my_function("ram")
my_function("rakesh")
# Out:
# ram kumar
# rakesh kumar

# %%
def my_function(fname,gname):
    print(fname + "and" + gname)

my_function("viv","suresh")
# Out:
# vivandsuresh

# %%
my_function("name")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 my_function("name")
#
# TypeError: my_function() missing 1 required positional argument: 'gname'

# %% [markdown]
# Number of arguments

# %%
def my_function(*guest):
    print("Guest is/are "+ guest[1])

my_function("Chin ","Tapak","Dam ")
# Out:
# Guest is/are Tapak
