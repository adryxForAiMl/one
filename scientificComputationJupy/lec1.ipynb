# %% [markdown]
# lecture -1(scientific computing using python)

# %%
print("hello Aditya")
# Out:
# hello Aditya

# %%
print("This is my first lecture")
# Out:
# This is my first lecture

# %%
import sys
print(sys.version)
# Out:
# 3.9.6 (default, Apr 17 2026, 18:15:52)
# [Clang 21.0.0 (clang-2100.1.1.101)]

# %%
3+4
# Out:
# 7

# %%
3*4
# Out:
# 12

# %%
3/2
# Out:
# 1.5

# %%
3**2
# Out:
# 9

# %%
72879744788*89789787
# Out:
# 6543856761128880156

# %%
7798/979899
# Out:
# 0.007957963014555581

# %% [markdown]
# indentation
# atleast ek space dete hai ,same level pe nahi rakhte

# %%
if 4>2 :
 print("four is greater than 2 ")
# Out:
# four is greater than 2

# %%
if 4>3:
    print("four is greater than three") #three spacing
    print("hello") #same spacing
# Out:
# four is greater than three
# hello

# %%
if 4>3:
    print("four is greater than three") #three spacing
     print("hello") #same spacing
# Out:
#   Cell In[21], line 3
#     print("hello") #same spacing
#     ^
# IndentationError: unexpected indent

# %%
if 4>3:
    print("four is greater than three") #three spacing
    print("hello") #same spacing
# Out:
# four is greater than three
# hello

# %%
print("hello world") #print command is used for display
# Out:
# hello world

# %% [markdown]
# Variables

# %%
x=5
y="python"
z=2.3
print(x)
print(y)
print(z)
# Out:
# 5
# python
# 2.3

# %%
x=5
y="python"
z=2.3
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# imaginary part ko j se denote karna hai python me

# %%
zz=2+3j #complex numbeer
print(type(zz))
# Out:
# <class 'complex'>

# %%
xx=2+3i
print(type(xx))
# Out:
#   Cell In[27], line 1
#     xx=2+3i
#           ^
# SyntaxError: invalid syntax

# %%
print("Delhi")
print('delhi')
# Out:
# Delhi
# delhi

# %% [markdown]
# #Variable names are case sensitive

# %%
x=5
X=("Delhi")
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
x=10
y=3+4j
z="haryana"
print(x,y,z)
print(x ,y ,z )
# Out:
# 10 (3+4j) haryana
# 10 (3+4j) haryana

# %% [markdown]
# Variables names

# %%
myvar = "hero"
my_var = "bihar"
_my_var= "hello"
myVar = "age"
MYVAR = "name"
myvar5 = "marks"
print(myvar)
# Out:
# hero

# %% [markdown]
# #illegal variabe names

# %%
5mvar = "not ok"
my-var = "this is also not ok"
my var ="not ok"
# Out:
#   Cell In[35], line 1
#     5mvar = "not ok"
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# various form of variables names(multi words)

# %%
thisCourseName = "Scientific Computing Using Python" #camel case

# %%
ThisCourseName = " Scientific Computing Using python" #pascal case

# %%
this_course_name = "Scientific Computing Using Python" #snake case
print(this_course_name)
# Out:
# Scientific Computing Using Python

# %%
3+445
# Out:
# 448
