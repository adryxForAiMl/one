# %% [markdown]
# Python operator

# %%
3+4
# Out:
# 7

# %%
3-4
# Out:
# -1

# %%
3*4
# Out:
# 12

# %%
-2*5
# Out:
# -10

# %%
3/4
# Out:
# 0.75

# %%
3**4
# Out:
# 81

# %%
3%2
# Out:
# 1

# %%
4%2
# Out:
# 0

# %%
10%3
# Out:
# 1

# %% [markdown]
# Python assignment operator

# %%
x=5
x+=3
print(x)
# Out:
# 8

# %%
x-3
# Out:
# 5

# %%
x=10
x-=4 #x=x-4
print(x)
# Out:
# 6

# %%
x=5
x*=5

# %%
x
# Out:
# 25

# %%
x=5
x*=5
print(x)
# Out:
# 25

# %%
x*=8
x
# Out:
# 200

# %%
x/10
# Out:
# 20.0

# %%
x
# Out:
# 200

# %%
x=40
x%=5
print(x)
# Out:
# 0

# %%
x
# Out:
# 0

# %%
x=x+18

# %%
x
# Out:
# 18

# %%
x%=5
print(x)
# Out:
# 3

# %%
x//=3 # x=x//3
print(x)
# Out:
# 1

# %%
x//=4

# %%
x=5
x//=2 #x=x//2
print(x)
# Out:
# 2

# %% [markdown]
# python condition and if statement

# %%
x=5
y=10
if y>x:
    print("Y is greater than x")
# Out:
# Y is greater than x

# %%
x=11
y=10
if y>x:
    print("Y is greater than x")

# %%
x=15
y=15
if y>x:
    print("y is greater than x")
elif x==y:
    print("y is equal to x")
else:
    print("x is greater than y")
# Out:
# y is equal to x

# %% [markdown]
# And logical operator

# %%
a=50
b=40
c=60
if a>b and c>a:
    print("Both condition are true")
# Out:
# Both condition are true

# %% [markdown]
# Or logical operator

# %%
a=40
b=40
c=60
if a>b or c>a:
    print("Either of the condition or Both conditions are true")
# Out:
# Either of the condition or Both condition are true

# %% [markdown]
# not equal to is represented by!

# %%
a=40
b=40
if a!=b:
    print("Both condition are true")

# %%
a=50
b=40
if a!=b:
    print(" a is not equal to b")
# Out:
#  a is not equal to b

# %%
a=40
b=40
if a<=b:
    print("a is less than equal to b")
# Out:
# a is less than equal to b

# %%
a=50
b=40
if a>=b:
    print("a is greater than or equal to b")
# Out:
# a is greater than or equal to b

# %% [markdown]
# nested if

# %%
x=20
if x>15:
    print("x is greater than 15")
    if x>25:
        print("x is greater than 25")
    else:
        print("Not above 25")
# Out:
# x is greater than 15
# Not above 25

# %%
x=10
if x>15:
    print("x is greater than 15")
    if x>25:
        print("x is greater than 25")
    else:
        print("Not above 25")

# %% [markdown]
# while loop

# %%
i=1
while i<=5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=0
while i<6:
    i+=1
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# for statement

# %%
set1=["mango","banana","apple"]
for x in set1:
    print(x)
# Out:
# mango
# banana
# apple

# %%
for x in "mango":
    print(x)
# Out:
# m
# a
# n
# g
# o

# %%
set1=["mango","banana","apple"]
for x in set1:
    print(x)
    if x=="banana":
        break
# Out:
# mango
# banana

# %%
set1=["mango","banana","apple"]
for x in set1:
    if x=="apple":
     print(x)
     break
# Out:
# apple

# %% [markdown]
# Range()function

# %%
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for x in range(2,6):
    print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
for x in range(2,21,3):
    print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20

# %%
for x in range(0,20,3):
    print(x)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18

# %%
set1=["blue","red","green"]
set2=["apple","mango","bananna"]
for x in set1:
    for y in set2:
        print(x,y)
# Out:
# blue apple
# blue mango
# blue bananna
# red apple
# red mango
# red bananna
# green apple
# green mango
# green bananna
