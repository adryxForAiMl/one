# %% [markdown]
# Python operator

# %%
3+4
# Out:
# 7

# %%
3-4
# Out:
# -1

# %%
3*4
# Out:
# 12

# %%
-2*5
# Out:
# -10

# %%
3/4
# Out:
# 0.75

# %%
3**4
# Out:
# 81

# %%
3%2
# Out:
# 1

# %%
4%2
# Out:
# 0

# %%
10%3
# Out:
# 1

# %% [markdown]
# Python assignment operator

# %%
x=5
x+=3
print(x)
# Out:
# 8

# %%
x-3
# Out:
# 5

# %%
x=10
x-=4 #x=x-4
print(x)
# Out:
# 6

# %%
x=5
x*=5

# %%
x
# Out:
# 30

# %%
x=5
x*=5
print(x)
# Out:
# 25

# %%
x*=8
x
# Out:
# 200

# %%
x/10
# Out:
# 20.0

# %%
x+2
# Out:
# 202
